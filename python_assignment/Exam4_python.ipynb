# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### <span style="color:blue">ETA to submit </span><span style="color:green">7-7-2026 THUR</span>

# %% [markdown]
# # Question 1
# Loop through a list of email addresses. If an email does not contain '@', use continue to skip it. If it contains '@gmail.com', print 'Gmail user detected'.
#
# **Sample Input:**
# ['john@gmail.com', 'invalidEmail', 'sara@yahoo.com']
#
# **Expected Output:**
# Gmail user detected

# %%
emails = ["john@gmail.com", "invalidEmail", "sara@yahoo.com"]

# %% [markdown]
# # Question 2
# Given a list of messages, stop processing when you find the word 'STOP'. Before that, print only messages that contain 'error'. Use break when 'STOP' is found.
#
# **Sample Input:**
# ['error: file missing', 'warning: low memory', 'STOP', 'error: disk full']
#
# **Expected Output:**
# error: file missing

# %%
messages = ["error: file missing", "warning: low memory", "STOP", "error: disk full"]

# %% [markdown]
# # Question 3
# Loop through usernames. If username length < 4, use continue. If username contains digits, print 'Strong username'. Else print 'Weak username'.
#
# **Sample Input:**
# ['sam', 'alex1', 'john']
#
# **Expected Output:**
# Strong username
# Weak username

# %%
usernames = ["sam", "alex1", "john"]

# %% [markdown]
# # Question 4
# Scan chat messages. If a message contains 'badword', stop the loop and print 'Profanity detected'. Use break.
#
# **Sample Input:**
# ['hello', 'how are you', 'this is badword', 'later']
#
# **Expected Output:**
# Profanity detected

# %%
messages = ["hello", "how are you", "this is badword", "later"]

# %% [markdown]
# # Question 5
# Given product codes, skip any code that doesn’t start with 'PRD-'. Print 'Valid product' for valid ones. Use continue.
#
# **Sample Input:**
# ['PRD-123', 'XYZ-999', 'PRD-888']
#
# **Expected Output:**
# Valid product
# Valid product

# %%
codes = ["PRD-123", "XYZ-999", "PRD-888"]

# %% [markdown]
# # Question 6
# Loop through daily temperature readings. Stop when you find a negative temperature. Before that, print only temperatures above 90. Use break.
#
# **Sample Input:**
# [85, 92, 95, -3, 88]
#
# **Expected Output:**
# 92
# 95

# %%
temps = [85, 92, 95, -3, 88]

# %% [markdown]
# # Question 7
# Loop through order IDs. Skip even numbers using continue. If odd number > 1000, print 'High priority order'.
#
# **Sample Input:**
# [1001, 1002, 999, 1501]
#
# **Expected Output:**
# High priority order
# High priority order

# %%
orders = [1001, 1002, 999, 1501]

# %% [markdown]
# # Question 8
# Given transaction amounts: If amount > 10000 print 'Flagged: Large transaction'. If amount < 0 print 'Invalid transaction' and stop the loop using break. Otherwise print 'Normal transaction'.
#
# **Sample Input:**
# [500, 12000, 300, -50, 700]
#
# **Expected Output:**
# Normal transaction
# Flagged: Large transaction
# Normal transaction
# Invalid transaction

# %%
transactions = [500, 12000, 300, -50, 700]

# %% [markdown]
# # Question 9
# Loop through purchase amounts. Skip purchases below 20 using continue. If amount between 20–100 print 'Small discount'. If amount > 100 print 'Big discount'.
#
# **Sample Input:**
# [10, 25, 150, 5, 80]
#
# **Expected Output:**
# Small discount
# Big discount
# Small discount

# %%
purchases = [10, 25, 150, 5, 80]

# %% [markdown]
# # Question 10
# Given game scores, stop when score reaches 50 or more using break. Before that, print 'Score too low' for each score < 50.
#
# **Sample Input:**
# [20, 35, 45, 55, 60]
#
# **Expected Output:**
# Score too low
# Score too low
# Score too low

# %%
scores = [20, 35, 45, 55, 60]

# %% [markdown]
# ### Save the file <span style="color:blue">'Exam4_python_YOUR_Name'</span><span style="color:green"> download the file -> email </span>
